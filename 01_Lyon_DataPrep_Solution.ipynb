# %% [markdown]
# # Predicting the occupancies of Belgian trains

# %% [markdown]
# ## 0. Tips and tricks Jupyter notebooks
#
# * Export your notebooks locally: File -> Download as -> html/ipynb (do both!) (NOTE: don't trust the virtual environment, always download your latest version locally!)
#
# * Shift + Enter to run a cell (or play button)
#
# * TAB for code completion!
#
# * Shells can be Code but also Markdown! (dropdown menu on top allows you to choose)
#
# * Cell -> Run All might come in useful
#
# * In case of problems you can always Kernel -> Restart
#
# * In the Jupyter start window you have a 'new' button on the upper right => to open a terminal, a new python3 notebook, etc.
#
# * You cannot upload very large files (>3GB) via the upload in Jupyter (bug), the datasets will always be available via een public Amazon url, so use wget or scp to get your data in /mnt on the virtual wall!

# %% [markdown]
# ## 1. Data Preparation
#
# ### Essential Libraries for Python Data Science

# %%
#vector/matrix library
import numpy as np
#data frame library (similar to R)
import pandas as pd

#visualization library
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

#regular expression library for data cleasning
import re

# %% [markdown]
# ### Detour: Get up to speed with python / pandas
#
# * If you are new to python have a look at the practicelab.ipynb in the github repo
# * If you are new to pandas take some time for:
#     - <a href="http://pandas.pydata.org/pandas-docs/stable/10min.html"> Pandas basics in 10 minutes </a>
#     - <a href="http://pandas.pydata.org/pandas-docs/stable/visualization.html"> Pandas for data visualizations </a>
#     - Use the pandas cheat sheet in the github repo
#
#
# #### TIP: Pandas dataframes are immutable, so appending a row creates a copies the old df in the new one => creating a df like this is an O(N^2) operation (I learnt this the hard way)

# %% [markdown]
# ### 1a. Dataset characteristics
#
# 1. Read the train and test datasets
# 2. How many records and how many features are in train and test sets?
# 3. What is the range of the querytime column (earliest + latest date)
# 4. Merge training and test data (data cleansing will be the same for both)
# 5. Drop columns querytype and user_agent since they contain no useful info, this will speedup future df calculations

# %%
#1
path_train = './data/training_data.nldjson'
path_test  = './data/test.nldjson'

# %%
#warning the input files are slightly different format, training data is in new-line delimited json, 
#testdata in regular json
df_train = pd.read_json(path_train, lines=True)
df_test = pd.read_json(path_test)

#to have a look at a dataframe just use head or tail
df_train.head(n=5)
# Out:
#                                                 post  \
# 0  {'connection': 'http://irail.be/connections/88...
# 1  {'connection': 'http://irail.be/connections/88...
# 2  {'connection': 'http://irail.be/connections/88...
# 3  {'connection': 'http://irail.be/connections/88...
# 4  {'connection': 'http://irail.be/connections/88...
#
#                    querytime  querytype  \
# 0  2016-07-27T20:05:51+02:00  occupancy
# 1  2016-07-27T20:06:11+02:00  occupancy
# 2  2016-07-27T20:08:57+02:00  occupancy
# 3  2016-07-27T20:09:08+02:00  occupancy
# 4  2016-07-27T20:11:01+02:00  occupancy
#
#                                           user_agent
# 0  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 1  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 2  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 3  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 4  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...

# %%
df_test.head(n=5)

# %%
#2
print("Number of records in training set: " + str(df_train.shape[0]))
print("Number of records in test set: " + str(df_test.shape[0]))
# Out:
# Number of records in training set: 5062
# Number of records in test set: 493

# %%
print("Features training data: " + str(list(df_train.columns)))
print("Features test data: " + str(list(df_test.columns)))
# Out:
# Features training data: ['post', 'querytime', 'querytype', 'user_agent']
# Features test data: ['id', 'post', 'querytime', 'querytype', 'user_agent']

# %%
#3
print('Querytime min (training): ' + str(df_train['querytime'].min()))
print('Querytime max (training): ' + str(df_train['querytime'].max()))
print()
print('Querytime min (test): ' + str(df_test['querytime'].min()))
print('Querytime max (test): ' + str(df_test['querytime'].max()))

# %%
#4
#merge train and test data AND reset the index
dataset_v1 = pd.concat([df_train, df_test]).reset_index(drop=True)    
dataset_v1.head(n=5)
# Out:
#    id                                               post  \
# 0 NaN  {'connection': 'http://irail.be/connections/88...
# 1 NaN  {'connection': 'http://irail.be/connections/88...
# 2 NaN  {'connection': 'http://irail.be/connections/88...
# 3 NaN  {'connection': 'http://irail.be/connections/88...
# 4 NaN  {'connection': 'http://irail.be/connections/88...
#
#                    querytime  querytype  \
# 0  2016-07-27T20:05:51+02:00  occupancy
# 1  2016-07-27T20:06:11+02:00  occupancy
# 2  2016-07-27T20:08:57+02:00  occupancy
# 3  2016-07-27T20:09:08+02:00  occupancy
# 4  2016-07-27T20:11:01+02:00  occupancy
#
#                                           user_agent
# 0  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 1  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 2  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 3  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 4  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...

# %%
#5
dataset_v2 = dataset_v1.drop(['querytype','user_agent'], axis=1)
dataset_v2.head(n=5)
# Out:
#    id                                               post  \
# 0 NaN  {'connection': 'http://irail.be/connections/88...
# 1 NaN  {'connection': 'http://irail.be/connections/88...
# 2 NaN  {'connection': 'http://irail.be/connections/88...
# 3 NaN  {'connection': 'http://irail.be/connections/88...
# 4 NaN  {'connection': 'http://irail.be/connections/88...
#
#                    querytime
# 0  2016-07-27T20:05:51+02:00
# 1  2016-07-27T20:06:11+02:00
# 2  2016-07-27T20:08:57+02:00
# 3  2016-07-27T20:09:08+02:00
# 4  2016-07-27T20:11:01+02:00

# %% [markdown]
# ### 1b. Parsing the columns
#
# 1. In the id column replace the NaNs with -1
# 2. Select a row by id and have a closer look at the post column (json object)
#     * check multiple rows since the post object doesn't always have the same fields
# 3. Iterate over the frame while keeping track of the possible fields in post => what is the set of ps
# 4. Write a function to extract a field of the json object
# 5. For every field in the json objects create an additional column, finally drop the post column
# 6. The query time column is now interpreted as a string => convert to datetime, the id column can be cast to integer

# %%
#1
transformed_column = dataset_v2['id'].apply(lambda i: -1 if pd.isnull(i) else i)
dataset_v2['id'] = transformed_column
dataset_v2.head(n=3)
# Out:
#     id                                               post  \
# 0 -1.0  {'connection': 'http://irail.be/connections/88...
# 1 -1.0  {'connection': 'http://irail.be/connections/88...
# 2 -1.0  {'connection': 'http://irail.be/connections/88...
#
#                    querytime
# 0  2016-07-27T20:05:51+02:00
# 1  2016-07-27T20:06:11+02:00
# 2  2016-07-27T20:08:57+02:00

# %%
#2
row = dataset_v2.iloc[2]
post_obj = row['post']
post_obj
# Out:
# {'connection': 'http://irail.be/connections/8813003/20160727/IC1518',
#  'date': '7000',
#  'from': 'http://irail.be/stations/NMBS/008813003',
#  'occupancy': 'http://api.irail.be/terms/high',
#  'to': 'http://irail.be/stations/NMBS/00',
#  'vehicle': 'http://irail.be/vehicle/IC1518'}

# %%
#3
all_keys = []
for r in dataset_v2.iterrows():
    new_keys = list(r[1]['post'].keys())
    all_keys.extend(new_keys)
    
unique_keys = set(all_keys)
unique_keys
# Out:
# {'connection', 'date', 'from', 'occupancy', 'to', 'vehicle'}

# %%
#4
def extract_field(json, field):
    if field in json:
        return json[field]
    else:
        return None

# %%
#test
dataset_v2['post'].apply(lambda j: extract_field(j, 'connection')).head()
# Out:
# 0    http://irail.be/connections/8813003/20160727/I...
# 1    http://irail.be/connections/8813003/20160727/I...
# 2    http://irail.be/connections/8813003/20160727/I...
# 3    http://irail.be/connections/8813003/20160727/I...
# 4    http://irail.be/connections/8813003/20160727/I...
# Name: post, dtype: object

# %%
#5
for k in unique_keys:
    new_col = dataset_v2['post'].apply(lambda j: extract_field(j, k))
    dataset_v2[k] = new_col
    
dataset_v3 = dataset_v2.drop('post', axis=1)    
dataset_v3.head()
# Out:
#     id                  querytime                                     date  \
# 0 -1.0  2016-07-27T20:05:51+02:00  Sun Jan 18 1970 01:14:03 GMT+0100 (CET)
# 1 -1.0  2016-07-27T20:06:11+02:00  Sun Jan 18 1970 01:14:03 GMT+0100 (CET)
# 2 -1.0  2016-07-27T20:08:57+02:00                                     7000
# 3 -1.0  2016-07-27T20:09:08+02:00                                     7000
# 4 -1.0  2016-07-27T20:11:01+02:00                                    11663
#
#                           vehicle  \
# 0  http://irail.be/vehicle/IC1518
# 1  http://irail.be/vehicle/IC1518
# 2  http://irail.be/vehicle/IC1518
# 3  http://irail.be/vehicle/IC1518
# 4  http://irail.be/vehicle/IC1518
#
#                                           connection  \
# 0  http://irail.be/connections/8813003/20160727/I...
# 1  http://irail.be/connections/8813003/20160727/I...
# 2  http://irail.be/connections/8813003/20160727/I...
# 3  http://irail.be/connections/8813003/20160727/I...
# 4  http://irail.be/connections/8813003/20160727/I...
#
#                                  to                       occupancy  \
# 0                              None  http://api.irail.be/terms/high
# 1                              None  http://api.irail.be/terms/high
# 2  http://irail.be/stations/NMBS/00  http://api.irail.be/terms/high
# 3  http://irail.be/stations/NMBS/00  http://api.irail.be/terms/high
# 4  http://irail.be/stations/NMBS/00  http://api.irail.be/terms/high
#
#                                       from
# 0  http://irail.be/stations/NMBS/008813003
# 1  http://irail.be/stations/NMBS/008813003
# 2  http://irail.be/stations/NMBS/008813003
# 3  http://irail.be/stations/NMBS/008813003
# 4  http://irail.be/stations/NMBS/008813003

# %%
#6
dataset_v3['querytime'] = pd.to_datetime(dataset_v3['querytime'])

#Later onderscheid tussen winter en zomeruur vermijden door niet naar UTC te gaan
#dataset_v3['querytime' = pd.to_datetime(dataset_v3['querytime'].apply(lambda t: t.split("+")[0]))

dataset_v3['id'] = pd.to_numeric(dataset_v3['id'], downcast='integer')


dataset_v3.dtypes
# Out:
# id                     int16
# querytime     datetime64[ns]
# date                  object
# vehicle               object
# connection            object
# to                    object
# occupancy             object
# from                  object
# dtype: object

# %% [markdown]
# ### 1.3 And some more cleansing
#
# - TASK: go over each of the columns, further parse them and pay close attention to NULL values
# - HINT: don't mindlessly drop rows with missing data, the dataset has some level of redundancy so pay close attention!
#
#
# 1. How many NULL values per column?
# 2. Rework the vehicle column:
#     - use the following information on the slides and at: https://nl.wikipedia.org/wiki/Lijst_van_treincategorie%C3%ABn_in_Belgi%C3%AB
#     - extract connection type, train series, sequence number and you can also infer the direction of the train
#     - keep checking for NULLs, some can be disguised (HINT: use the value_counts() function to check the distribution of values in a column)
#
# 4. connection
# 5. date
# 6. occupancy
# 7. to, from columns

# %%
#1

pd.isnull(dataset_v3['vehicle'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 5525    False
# 5526    False
# 5527    False
# 5528    False
# 5529    False
# 5530    False
# 5531    False
# 5532    False
# 5533    False
# 5534    False
# 5535    False
# 5536    False
# 5537    False
# 5538    False
# 5539    False
# 5540    False
# 5541    False
# 5542    False
# 5543    False
# 5544    False
# 5545    False
# 5546    False
# 5547    False
# 5548    False
# 5549    False
# 5550    False
# 5551    False
# 5552    False
# 5553    False
# 5554    False
# Name: vehicle, Length: 5555, dtype: bool

# %%
for col in dataset_v3.columns:
    print(col + "\t"+ str(dataset_v3[pd.isnull(dataset_v3[col])].shape[0]))
# Out:
# id	0
# querytime	0
# date	0
# vehicle	0
# connection	0
# to	12
# occupancy	493
# from	0

# %%
dataset_v3[pd.isnull(dataset_v3['to'])]
# Out:
#     id           querytime                                     date  \
# 0   -1 2016-07-27 18:05:51  Sun Jan 18 1970 01:14:03 GMT+0100 (CET)
# 1   -1 2016-07-27 18:06:11  Sun Jan 18 1970 01:14:03 GMT+0100 (CET)
# 21  -1 2016-07-27 18:31:32                                 20160727
# 22  -1 2016-07-27 18:31:55                                 20160727
# 23  -1 2016-07-27 18:32:59                                 20160727
# 24  -1 2016-07-27 18:35:51                                 20160727
# 25  -1 2016-07-27 18:35:58                                 20160727
# 26  -1 2016-07-27 18:36:02                                 20160727
# 27  -1 2016-07-27 18:36:05                                 20160727
# 28  -1 2016-07-27 18:36:15                                 20160727
# 29  -1 2016-07-27 18:36:42                                 20160727
# 30  -1 2016-07-27 18:36:45                                 20160727
#
#                            vehicle  \
# 0   http://irail.be/vehicle/IC1518
# 1   http://irail.be/vehicle/IC1518
# 21  http://irail.be/vehicle/IC1518
# 22  http://irail.be/vehicle/IC1518
# 23  http://irail.be/vehicle/IC1518
# 24  http://irail.be/vehicle/IC1518
# 25  http://irail.be/vehicle/IC1518
# 26  http://irail.be/vehicle/IC1518
# 27  http://irail.be/vehicle/IC1518
# 28  http://irail.be/vehicle/IC1518
# 29  http://irail.be/vehicle/IC1518
# 30  http://irail.be/vehicle/IC1518
#
#                                            connection    to  \
# 0   http://irail.be/connections/8813003/20160727/I...  None
# 1   http://irail.be/connections/8813003/20160727/I...  None
# 21  http://irail.be/connections/8813003/20160727/I...  None
# 22  http://irail.be/connections/8813003/20160727/I...  None
# 23  http://irail.be/connections/8813003/20160727/I...  None
# 24  http://irail.be/connections/8813003/20160727/I...  None
# 25  http://irail.be/connections/8813003/20160727/I...  None
# 26  http://irail.be/connections/8813003/20160727/I...  None
# 27  http://irail.be/connections/8813003/20160727/I...  None
# 28  http://irail.be/connections/8813003/20160727/I...  None
# 29  http://irail.be/connections/8813003/20160727/I...  None
# 30  http://irail.be/connections/8813003/20160727/I...  None
#
#                            occupancy                                     from
# 0     http://api.irail.be/terms/high  http://irail.be/stations/NMBS/008813003
# 1     http://api.irail.be/terms/high  http://irail.be/stations/NMBS/008813003
# 21  http://api.irail.be/terms/medium  http://irail.be/stations/NMBS/008813003
# 22  http://api.irail.be/terms/medium  http://irail.be/stations/NMBS/008813003
# 23  http://api.irail.be/terms/medium  http://irail.be/stations/NMBS/008813003
# 24    http://api.irail.be/terms/high  http://irail.be/stations/NMBS/008813003
# 25    http://api.irail.be/terms/high  http://irail.be/stations/NMBS/008813003
# 26    http://api.irail.be/terms/high  http://irail.be/stations/NMBS/008813003
# 27    http://api.irail.be/terms/high  http://irail.be/stations/NMBS/008813003
# 28    http://api.irail.be/terms/high  http://irail.be/stations/NMBS/008813003
# 29    http://api.irail.be/terms/high  http://irail.be/stations/NMBS/008813003
# 30    http://api.irail.be/terms/high  http://irail.be/stations/NMBS/008813003

# %%
#2
def remove_url_prefix(s):
    return s.split('/')[-1]

dataset_v3['vehicle'] = dataset_v3['vehicle'].apply(remove_url_prefix)
dataset_v3['vehicle'].value_counts()
# Out:
# (null)      951
# IC1515       43
# IC1518       36
# IC429        33
# IC407        31
# P7305        30
# IC1807       24
# P7013        23
# IC1530       23
# IC539        23
# IC716        22
# S68574       22
# S61555       22
# IC1534       21
# IC3631       20
# IC1507       20
# IC1839       19
# IC437        19
# IC1514       19
# IC1509       18
# P7444        18
# IC3328       18
# L557         17
# IC408        17
# IC515        17
# IC4516       17
# S11757       16
# IC3639       16
# IC3604       16
# S83978       16
#            ...
# IC3835        1
# L2892         1
# IC822         1
# IC617         1
# IC2917        1
# S86589        1
# IC717         1
# L2579         1
# THA9308       1
# IC2422        1
# S86576        1
# S53364        1
# EXT12420      1
# IC3111        1
# IC1711        1
# L2764         1
# IC2840        1
# S206467       1
# S83957        1
# ICE11         1
# IC419         1
# IC1719        1
# L5565         1
# IC3037        1
# IC5385        1
# IC3844        1
# P7489         1
# IC2337        1
# S53379        1
# S23786        1
# Name: vehicle, Length: 1421, dtype: int64

# %%
def remove_irregulars(s):
    if pd.isnull(s):
        return s
    else:
        if s=='(null)':
            return None
        else:
            return s

dataset_v3['vehicle'] = dataset_v3['vehicle'].apply(remove_irregulars)
dataset_v3['vehicle'].value_counts()
dataset_v3[pd.isnull(dataset_v3['vehicle'])].head(n=5)
# Out:
#       id           querytime      date vehicle  \
# 3382  -1 2016-12-02 15:32:02  20161202    None
# 3383  -1 2016-12-02 15:34:07  20161202    None
# 3568  -1 2016-12-09 06:22:34  20161209    None
# 3570  -1 2016-12-09 06:31:41  20161209    None
# 3571  -1 2016-12-09 06:31:48  20161209    None
#
#                                              connection  \
# 3382  http://irail.be/connections/8833001/20161202/I...
# 3383  http://irail.be/connections/8812005/20161202/I...
# 3568  http://irail.be/connections/8814001/20161209/P...
# 3570  http://irail.be/connections/8813003/20161209/P...
# 3571  http://irail.be/connections/8812005/20161209/P...
#
#                                            to  \
# 3382  http://irail.be/stations/NMBS/008812005
# 3383  http://irail.be/stations/NMBS/008833001
# 3568  http://irail.be/stations/NMBS/008813003
# 3570  http://irail.be/stations/NMBS/008812005
# 3571  http://irail.be/stations/NMBS/008811007
#
#                              occupancy  \
# 3382  http://api.irail.be/terms/medium
# 3383    http://api.irail.be/terms/high
# 3568     http://api.irail.be/terms/low
# 3570     http://api.irail.be/terms/low
# 3571     http://api.irail.be/terms/low
#
#                                          from
# 3382  http://irail.be/stations/NMBS/008833001
# 3383  http://irail.be/stations/NMBS/008812005
# 3568  http://irail.be/stations/NMBS/008814001
# 3570  http://irail.be/stations/NMBS/008813003
# 3571  http://irail.be/stations/NMBS/008812005

# %%
#INZICHT vehicle types zitten ook in connection => daar extraheren

dataset_v3.iloc[0]['connection']
# Out:
# 'http://irail.be/connections/8813003/20160727/IC1518'

# %%
def extract_train_series_id(r):
    series_number = int(re.sub(r"[a-zA-Z]", "", r)) 
    return series_number % 100 

def extract_train_series(r):
    series_number = int(re.sub(r"[a-zA-Z]", "", r)) 
    return series_number // 100 * 100
               
def extract_train_direction(r):
    series_id = extract_train_series_id(r)
    series_div = (series_id // 25) % 2
    return 'away' if series_div == 0 else 'back'



def extract_train_type(r):
    return re.sub(r"[0-9]", "", r.upper())

# %%
#3

# %%
dataset_v4 = dataset_v3.drop(['vehicle','date'],axis=1)
dataset_v4['vehicle'] = dataset_v4['connection'].apply(lambda r: r.split('/')[-1])
dataset_v4['vehicle'].value_counts()
# Out:
# IC1515     69
# IC1518     48
# IC407      35
# IC429      35
# IC539      34
# P7305      33
# S61555     27
# IC1807     27
# IC1534     26
# S32266     25
# IC716      25
# S86567     24
# IC1530     24
# IC4516     23
# P7013      23
# S68574     22
# IC507      21
# IC1839     21
# IC1507     21
# S83978     21
# IC437      20
# IC3631     19
# IC515      19
# IC1509     19
# P7444      19
# IC1514     18
# IC408      18
# IC415      18
# IC3328     18
# IC529      17
#            ..
# IC9248      1
# S23661      1
# S83988      1
# IC3013      1
# IC929       1
# IC2242      1
# S11983      1
# IC1743      1
# IC3312      1
# IC2317      1
# IC420       1
# IC2441      1
# THA9351     1
# IC628       1
# IC12614     1
# IC3209      1
# P7091       1
# L2887       1
# IC1912      1
# IC3408      1
# L2485       1
# S102077     1
# L5593       1
# S11763      1
# S73460      1
# L4882       1
# IC2612      1
# IC4340      1
# IC3730      1
# IC3240      1
# Name: vehicle, Length: 1536, dtype: int64

# %%
dataset_v4['train_series']    = dataset_v4['vehicle'].apply(extract_train_series)
dataset_v4['train_direction'] = dataset_v4['vehicle'].apply(extract_train_direction)
dataset_v4['train_type']      = dataset_v4['vehicle'].apply(extract_train_type)


dataset_v5 = dataset_v4.drop(['vehicle','connection'], axis=1)

# 5554            away         IC
#
# [5555 rows x 8 columns]

# %%
#6
dataset_v5['from'].describe()
# Out:
# count                                        5555
# unique                                        391
# top       http://irail.be/stations/NMBS/008892007
# freq                                          492
# Name: from, dtype: object

# %%
dataset_v5['to'].describe()
# Out:
# count                                        5543
# unique                                        400
# top       http://irail.be/stations/NMBS/008814001
# freq                                          470
# Name: to, dtype: object

# %%
mask = pd.isnull(dataset_v5['to'])
dataset_v5[mask]
# Out:
#     id           querytime    to occupancy  \
# 0   -1 2016-07-27 18:05:51  None      high
# 1   -1 2016-07-27 18:06:11  None      high
# 21  -1 2016-07-27 18:31:32  None    medium
# 22  -1 2016-07-27 18:31:55  None    medium
# 23  -1 2016-07-27 18:32:59  None    medium
# 24  -1 2016-07-27 18:35:51  None      high
# 25  -1 2016-07-27 18:35:58  None      high
# 26  -1 2016-07-27 18:36:02  None      high
# 27  -1 2016-07-27 18:36:05  None      high
# 28  -1 2016-07-27 18:36:15  None      high
# 29  -1 2016-07-27 18:36:42  None      high
# 30  -1 2016-07-27 18:36:45  None      high
#
#                                        from  train_series train_direction  \
# 0   http://irail.be/stations/NMBS/008813003          1500            away
# 1   http://irail.be/stations/NMBS/008813003          1500            away
# 21  http://irail.be/stations/NMBS/008813003          1500            away
# 22  http://irail.be/stations/NMBS/008813003          1500            away
# 23  http://irail.be/stations/NMBS/008813003          1500            away
# 24  http://irail.be/stations/NMBS/008813003          1500            away
# 25  http://irail.be/stations/NMBS/008813003          1500            away
# 26  http://irail.be/stations/NMBS/008813003          1500            away
# 27  http://irail.be/stations/NMBS/008813003          1500            away
# 28  http://irail.be/stations/NMBS/008813003          1500            away
# 29  http://irail.be/stations/NMBS/008813003          1500            away
# 30  http://irail.be/stations/NMBS/008813003          1500            away
#
#    train_type
# 0          IC
# 1          IC
# 21         IC
# 22         IC
# 23         IC
# 24         IC
# 25         IC
# 26         IC
# 27         IC
# 28         IC
# 29         IC
# 30         IC

# %%
dataset_v6 = dataset_v5.drop(dataset_v5[mask].index)

# %%
dataset_v6['from'].describe()

# %%
dataset_v6['from'] = dataset_v6['from'].apply(lambda r: r.strip().split('/')[-1])
dataset_v6['to'] = dataset_v6['to'].apply(lambda r: r.strip().split('/')[-1])

# %%
mask = dataset_v6['from'].str.len() != 9
print(dataset_v6[mask].shape)
dataset_v6[mask]

# %%
dataset_v7 = dataset_v6.drop(dataset_v6[mask].index)
dataset_v7.shape

# %%
dataset_v7.loc[32,'to'] = "00" +  dataset_v7.loc[32,'to']

# %%
mask = dataset_v7['to'].str.len() != 9
print(dataset_v7[mask].shape)
dataset_v7[mask]

# %%
dataset_v8 = dataset_v7.drop(dataset_v7[mask].index)
dataset_v8.shape

# %%
dataset_v8['from'] = dataset_v8['from'].apply(lambda t: t[2:])
dataset_v8['to'] = dataset_v8['to'].apply(lambda t: t[2:])

# %%
print(dataset_v8[dataset_v8['id'] == -1].shape)
print(dataset_v8[dataset_v8['id'] != -1].shape)

dataset_v8.to_csv('json_cleaned.csv', header=True, sep=',', index=False)
